# %%
import pandas as pd
import numpy as np

# %%
#question_1
pd.__version__
# Out:
# '3.0.6'

# %%
#question_2
df = pd.read_csv("car_fuel_efficiency_2026.csv")
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
#question_3
listOfFuelTypes = pd.unique(df["fuel_type"])
numberOfFuelTypes = len(listOfFuelTypes)
numberOfFuelTypes
# Out:
# 3

# %%
#question_4
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
#question_5
asianListOfCars = df[df["origin"] == "Asia"]
maximumFuelEfficiency = max(asianListOfCars["fuel_efficiency_mpg"])
maximumFuelEfficiency
# Out:
# 41.2

# %%
medianHorsePower = df['horsepower'].median()
medianHorsePower
# Out:
# np.float64(254.0)

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 252.0    174
# 246.0    168
# 256.0    168
# 259.0    165
# 253.0    165
#         ...
# 322.0      1
# 330.0      1
# 175.0      1
# 178.0      1
# 320.0      1
# Name: count, Length: 153, dtype: int64

# %%
df['horsepower'].mode()
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'].value_counts().iloc[0]
# Out:
# np.int64(174)

# %%
#question_6
mostFrequentHorsepower = df['horsepower'].mode()[0]
df['horsepower'] = df['horsepower'].fillna(mostFrequentHorsepower)
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %%
asianListOfCars
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# ...

# %%
subSet_df = asianListOfCars[['vehicle_weight', 'model_year']]
subSet_df
# Out:
#       vehicle_weight  model_year
# 2               4240        1996
# 6               4310        1992
# 8               4230        1997
# 10              4420        1978
# 15              3950        2007
# ...              ...         ...
# 9984            4610        2011
# 9987            4530        2004
# 9990            3630        1975
# 9994            4610        1993
# 9996            4370        1993
#
# [2994 rows x 2 columns]

# %%
subSet_df = subSet_df.iloc[0:7, :]

# %%
X = subSet_df.values
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
iXTX = np.linalg.inv(XTX)
iXTX
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
w = iXTX.dot(X.T).dot(y)

# %%
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
#question_7
w.sum()
# Out:
# np.float64(0.36919696904925486)
